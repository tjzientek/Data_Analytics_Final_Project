# %%
import pandas as pd
import json
import os

filepath = os.path.join("senators.json")
with open(filepath) as jsonfile:
    data_json = json.load(jsonfile)

# %%
data = data_json

# %%
datarow = {}
data_list = []
x = 0

while x < len(data[0]):
    first_name = data[0][x]['first_name']
    last_name = data[0][x]['last_name']
    middle_name = data[0][x]['middle_name']
    party = data[0][x]['terms'][0]['party']
    state = data[0][x]['terms'][0]['state']
    year_start = data[0][x]['terms'][0]['year_start']
    year_end = data[0][x]['terms'][0]['year_end']
    datarow = {'first_name':first_name, 'last_name':last_name, 'middle_name':middle_name, 'party':party, \
               'state':state, 'year_start':year_start, 'year_end':year_end}
    data_list.append(datarow)
    x += 1

df = pd.DataFrame(data_list)
df.head()
# Out:
#   first_name last_name middle_name       party state year_end year_start
# 0     Joseph    Abbott      Carter  Republican    NC     1872       1868
# 1      James    Abdnor              Republican    SD     1987       1981
# 2      Hazel      Abel              Republican    NE     1954       1954
# 3      James  Abourezk              Democratic    SD     1979       1973
# 4    Spencer   Abraham              Republican    MI     2001       1995

# %%
df.to_csv("senators.csv", index=False, header=True)

# %%
year = 1789
year_parties = []


while year < 2018:
    
    dem_count = 0
    rep_count = 0
    fed_count = 0
    whig_count = 0
    demrep_count = 0
    oth_count = 0
    x = 0
    while x < len(data[0]):
        party = data[0][x]['terms'][0]['party']
        year_start = data[0][x]['terms'][0]['year_start']
        if (year_start.find('-') > 0):
            year_start = year_start.split("-",1)[0]
        year_end = data[0][x]['terms'][0]['year_end']
        if (year_end.find('-') > 0):
            year_end = year_end.split("-",1)[0]
        #print(f"Party: {party}, Year: {int(year_start)}, {int(year_end)}")
        r = range(int(year_start),int(year_end))
        if (int(year_start) <= year <= int(year_end)):
            #print(f"Year: {year}, X Row: {x}")
            if (party == "Democratic"):
                dem_count += 1
            elif (party == "Republican"):
                rep_count += 1
            elif (party == "Federalist"):
                fed_count += 1
            elif (party == "Whig"):
                whig_count += 1
            elif (party == "Democratic-Republican"):
                demrep_count += 1
            else:
                oth_count += 1
        x += 1   
    year_parties.append({'year':year, 'democrats':dem_count, 'republicans':rep_count, \
                         'federalist':fed_count, 'whig':whig_count, 'democratic-republicans':demrep_count, \
                         'others':oth_count})
 
    year += 1

# %%
df_years = pd.DataFrame(year_parties)
df_years
# Out:
#      democratic-republicans  democrats  federalist  others  republicans  whig  \
# 0                         6          0          18       0            0     0
# 1                         8          0          21       0            0     0
# 2                        10          0          22       0            0     0
# 3                        12          0          17       0            0     0
# 4                        14          0          22       0            0     0
# 5                        13          0          17       0            0     0
# 6                        11          0          24       0            0     0
# 7                        12          0          28       0            0     0
# 8                        14          0          23       0            0     0
# 9                        11          0          25       0            0     0
# 10                       11          0          24       0            0     0
